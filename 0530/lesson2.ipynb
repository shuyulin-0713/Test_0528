# %%
students = {
	'chinese':89,
	'english':94,
	'math':65,
	'history':92,
	'discover': 95}
	
print(students)
	
print(students['chinese'])
print(students['math'])
print(students['discover'])
print(students['english'])
print(students['history'])



for key in students:
	print(key) 
	
for key in students:
	print(students[key])
# Out:
# {'chinese': 89, 'english': 94, 'math': 65, 'history': 92, 'discover': 95}
# 89
# 65
# 95
# 94
# 92
# chinese
# english
# math
# history
# discover
# 89
# 94
# 65
# 92
# 95
