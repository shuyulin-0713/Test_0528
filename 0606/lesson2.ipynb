# %%
def main():
    print("這裏是main function的命名空間")
   
if __name__ == '__main__':
    n = 10
    print(n)
    main()
# Out:
# 10
# 這裏是main function的命名空間

# %%
def main():
    print("這裏是main function的命名空間")
    print(n)
   
if __name__ == '__main__':
    n = 10
    main()
# Out:
# 這裏是main function的命名空間
# 10

# %%
def main():
    print("這裏是main function的命名空間")
    print(n)
   
if __name__ == '__main__':
    n = 10
    main()
    print(n)
# Out:
# 這裏是main function的命名空間
# 10
# 10

# %%
def main():
    n=10
    print("這裏是main function的命名空間")
    print(n)
   
if __name__ == '__main__':
    main()
# Out:
# 這裏是main function的命名空間
# 10
